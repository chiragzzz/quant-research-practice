# %%
# https://www.codecademy.com/learn/learn-python-3 #

# %%
def compare_prices(stock1, price1, stock2, price2):
    if price1 > price2:
        return f"{stock1} is greter than {stock2}"
    else:
        return f"{stock2} is greter than {stock1}"

# %%
compare_prices("APPL", 100, "AMZ", 10)
# Out:
# 'APPL is greter than AMZ'

# %%
stocks = ['AAPL', 'GOOG', 'MSFT']
for stock in stocks:
    print(f"{stock} is a tech stock")
# Out:
# AAPL is a tech stock
# GOOG is a tech stock
# MSFT is a tech stock

# %% [markdown]
# ##DAY 2##

# %%
# Load and inspect the data

# Clean and rename columns

# Filter useful dates and remove unnecessary columns

# Plot a simple price trend

# Save the cleaned dataset

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv"
df = pd.read_csv(url)
df.tail()
# Out:
#            Date   AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close  AAPL.Volume  \
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995     20065500
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993     23035400
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004     32815500
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995     35501600
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006     22118000
#
#      AAPL.Adjusted          dn        mavg          up   direction
# 501     132.119995  114.494004  124.498666  134.503328  Decreasing
# 502     133.289993  114.820798  125.205166  135.589534  Increasing
# 503     135.020004  115.175718  125.953499  136.731280  Increasing
# 504     135.509995  115.545035  126.723499  137.901963  Decreasing
# 505     135.350006  116.203299  127.504333  138.805366  Decreasing

# %%
# Exploring data

print(df.columns)
print(df.shape)
df.info()
df.describe()
# Out:
# Index(['Date', 'AAPL.Open', 'AAPL.High', 'AAPL.Low', 'AAPL.Close',
#        'AAPL.Volume', 'AAPL.Adjusted', 'dn', 'mavg', 'up', 'direction'],
#       dtype='object')
# (506, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           506 non-null    object
#  1   AAPL.Open      506 non-null    float64
#  2   AAPL.High      506 non-null    float64
#  3   AAPL.Low       506 non-null    float64
#  4   AAPL.Close     506 non-null    float64
#  5   AAPL.Volume    506 non-null    int64
#  6   AAPL.Adjusted  506 non-null    float64
#  7   dn             506 non-null    float64
#  8   mavg           506 non-null    float64
#  9   up             506 non-null    float64
#  10  direction      506 non-null    object
# dtypes: float64(8), int64(1), object(2)
# memory usage: 43.6+ KB
#         AAPL.Open   AAPL.High    AAPL.Low  AAPL.Close   AAPL.Volume  \
# count  506.000000  506.000000  506.000000  506.000000  5.060000e+02
# mean   112.935000  113.919447  111.942016  112.958340  4.317842e+07
# std     11.287490   11.251892   11.263687   11.244744  1.985253e+07
# min     90.000000   91.669998   89.470001   90.339996  1.147590e+07
# 25%    105.482500  106.349999  104.657501  105.672499  2.974240e+07
# 50%    112.889999  114.145001  111.800003  113.025002  3.747460e+07
# 75%    122.267498  123.497500  121.599998  122.179998  5.076395e+07
# max    135.669998  136.270004  134.839996  135.509995  1.622063e+08
#
#        AAPL.Adjusted          dn        mavg          up
# count     506.000000  506.000000  506.000000  506.000000
# mean      110.459312  107.311385  112.739865  118.168345
# std        10.537529   11.095804   10.595315   10.670752
# min        89.008370   85.508858   94.047166   97.572721
# 25%       103.484803   97.011245  104.954875  111.052267
# 50%       110.821123  107.351628  112.799750  118.472542
# 75%       119.255457  114.812152  121.889416  128.515793
# max       135.509995  127.289258  129.845000  138.805366

# %%
# Cleaning column names and Dropping unnecessry columns

df.columns = [col.strip().replace(" ", "_") for col in df.columns]

df = df.rename(columns={"AAPL.Close": "Close", "AAPL.Open": "Open", "AAPL.High": "High", "AAPL.Low": "Low"})
df = df.drop(columns = ["AAPL.Volume", "AAPL.Adjusted", "dn", "up"], errors="ignore")

df
# Out:
#            Date        Open        High         Low       Close        mavg  \
# 0    2015-02-17  127.489998  128.880005  126.919998  127.830002  117.927667
# 1    2015-02-18  127.629997  128.779999  127.449997  128.720001  118.940333
# 2    2015-02-19  128.479996  129.029999  128.330002  128.449997  119.889167
# 3    2015-02-20  128.619995  129.500000  128.050003  129.500000  120.763500
# 4    2015-02-23  130.020004  133.000000  129.660004  133.000000  121.720167
# ..          ...         ...         ...         ...         ...         ...
# 501  2017-02-10  132.460007  132.940002  132.050003  132.119995  124.498666
# 502  2017-02-13  133.080002  133.820007  132.750000  133.289993  125.205166
# 503  2017-02-14  133.470001  135.089996  133.250000  135.020004  125.953499
# 504  2017-02-15  135.520004  136.270004  134.619995  135.509995  126.723499
# 505  2017-02-16  135.669998  135.899994  134.839996  135.350006  127.504333
#
#       direction
# 0    Increasing
# 1    Increasing
# 2    Decreasing
# 3    Increasing
# 4    Increasing
# ..          ...
# 501  Decreasing
# 502  Increasing
# 503  Increasing
# 504  Decreasing
# 505  Decreasing
#
# [506 rows x 7 columns]

# %%
# Filter by date

df["Date"] = pd.to_datetime(df["Date"])
df = df[df["Date"] >= "2017-01-01"]

df
# Out:
#           Date        Open        High         Low       Close        mavg  \
# 474 2017-01-03  115.800003  116.330002  114.760002  116.150002  114.832833
# 475 2017-01-04  115.849998  116.510002  115.750000  116.019997  115.181000
# 476 2017-01-05  115.919998  116.860001  115.809998  116.610001  115.510667
# 477 2017-01-06  116.779999  118.160004  116.470001  117.910004  115.863333
# 478 2017-01-09  117.949997  119.430000  117.940002  118.989998  116.216833
# 479 2017-01-10  118.769997  119.379997  118.300003  119.110001  116.480667
# 480 2017-01-11  118.739998  119.930000  118.599998  119.750000  116.772167
# 481 2017-01-12  118.900002  119.300003  118.209999  119.250000  116.970500
# 482 2017-01-13  119.110001  119.620003  118.809998  119.040001  117.155500
# 483 2017-01-17  118.339996  120.239998  118.220001  120.000000  117.333500
# 484 2017-01-18  120.000000  120.500000  119.709999  119.989998  117.534833
# 485 2017-01-19  119.400002  120.089996  119.370003  119.779999  117.692667
# 486 2017-01-20  120.449997  120.449997  119.730003  120.000000  117.843500
# 487 2017-01-23  120.000000  120.809998  119.769997  120.080002  118.000500
# 488 2017-01-24  119.550003  120.099998  119.500000  119.970001  118.186000
# 489 2017-01-25  120.419998  122.099998  120.279999  121.879997  118.446500
# 490 2017-01-26  121.669998  122.440002  121.599998  121.940002  118.687000
# 491 2017-01-27  122.139999  122.349998  121.599998  121.949997  118.935667
# 492 2017-01-30  120.930000  121.629997  120.660004  121.629997  119.163667
# 493 2017-01-31  121.150002  121.389999  120.620003  121.349998  119.412167
# 494 2017-02-01  127.029999  130.490005  127.010002  128.750000  120.062333
# 495 2017-02-02  127.980003  129.389999  127.779999  128.529999  120.686000
# 496 2017-02-03  128.309998  129.190002  128.160004  129.080002  121.305167
# 497 2017-02-06  129.130005  130.500000  128.899994  130.289993  121.924333
# 498 2017-02-07  130.539993  132.089996  130.449997  131.529999  122.552833
# 499 2017-02-08  131.350006  132.220001  131.220001  132.039993  123.197666
# 500 2017-02-09  131.649994  132.449997  131.119995  132.419998  123.826166
# 501 2017-02-10  132.460007  132.940002  132.050003  132.119995  124.498666
# 502 2017-02-13  133.080002  133.820007  132.750000  133.289993  125.205166
# 503 2017-02-14  133.470001  135.089996  133.250000  135.020004  125.953499
# 504 2017-02-15  135.520004  136.270004  134.619995  135.509995  126.723499
# 505 2017-02-16  135.669998  135.899994  134.839996  135.350006  127.504333
#
#       direction
# 474  Increasing
# 475  Increasing
# 476  Increasing
# 477  Increasing
# 478  Increasing
# 479  Increasing
# 480  Increasing
# 481  Increasing
# 482  Decreasing
# 483  Increasing
# 484  Decreasing
# 485  Increasing
# 486  Decreasing
# 487  Increasing
# 488  Increasing
# 489  Increasing
# 490  Increasing
# 491  Decreasing
# 492  Increasing
# 493  Increasing
# 494  Increasing
# 495  Increasing
# 496  Increasing
# 497  Increasing
# 498  Increasing
# 499  Increasing
# 500  Increasing
# 501  Decreasing
# 502  Increasing
# 503  Increasing
# 504  Decreasing
# 505  Decreasing

# %%
# Plot the closing price

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,5))
plt.plot(df["Date"], df["Close"], label = "APPL Close", color = "green")
plt.title("Apple Closing Price (2017–Present)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Save the Cleaned Data

# %%
df.to_csv("apple_cleaned.csv", index=False)
